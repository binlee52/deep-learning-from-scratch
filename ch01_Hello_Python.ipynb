# %% [markdown]
# <a href="https://colab.research.google.com/github/binlee52/deep-learning-from-scratch/blob/master/ch01_Hello_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %%
x = np.array([1., 2., 3.])
y = np.array([2., 4., 6.])
print(type(x))
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# <class 'numpy.ndarray'>
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]

# %%
# broadcasting
x/2.
# Out:
# array([0.5, 1. , 1.5])

# %%
A = np.array([[1, 2], [3, 4]])
print(A)
print(A.shape)
print(A.dtype)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# int64

# %%
B = np.array([[3, 0], [0, 6]])

# %%
A+B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A*B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A*10
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
print(X[0])
# Out:
# [51 55]

# %%
print(X[0][1])
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten() # X를 1차원 배열로 변환(flatten)
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0, 2, 4])]
# Out:
# array([51, 14,  0])

# %%
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %%
import numpy as np
import matplotlib.pyplot as plt

# prepare data
x = np.arange(0, 6, 0.1)
y = np.sin(x)

# draw graph
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# prepare data
x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# draw graph
plt.plot(x, y1, label='sin')
plt.plot(x, y2, linestyle='--', label='cos')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin & cos')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('/content/drive/My Drive/Colab Notebooks/datasets/image/lena.png')

plt.imshow(img)
plt.show()
